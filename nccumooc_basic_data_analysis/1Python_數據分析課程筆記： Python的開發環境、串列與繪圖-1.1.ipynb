# %% [markdown]
# # 1.1 Jupyter的魔術指令

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# - inline表示直接於網頁中顯示結果。(不建議使用)

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
plot([-1, 2, 5, -3, -2])

# %%
randn(10)
# Out:
# array([ 0.67361415, -0.41482076, -0.77804236,  0.78797352,  0.23157863,
#        -0.49077481, -0.90950941,  0.81787653, -0.14486761,  1.70138534])

# %%
plot(randn(100))

# %%
plot([-1, 2, 5, -3, -2], [0, 2, 2.5, 4, 8])

# %% [markdown]
# - 在plot裡放入兩組字串，分別代表xy軸資訊，並將各點相連。
